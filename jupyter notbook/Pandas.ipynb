# %%
import pandas as pd
df = pd.read_csv("E:tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df["total_bill"].max()
# Out:
# np.float64(50.81)

# %%
df["tip"][df["sex"]=="Female"].mean()
# Out:
# np.float64(2.8334482758620685)

# %%
df.fillna(0,inplace=True)

# %%
import pandas as pd
df = pd.read_csv("weather_data.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
rows, cols = df.shape # Shape Gives dimensions
print(rows)
print(cols)
# Out:
# 6
# 4

# %%
df.head() # Gives first 5 rows
df.tail() # Gives last 5 rows
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.day  #both gives same answer
df["day"]
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df[["event","day"]]
# Out:
#    event       day
# 0   Rain  1/1/2017
# 1  Sunny  1/2/2017
# 2   Snow  1/3/2017
# 3   Snow  1/4/2017
# 4   Rain  1/5/2017
# 5  Sunny  1/6/2017

# %%
max_Temp = df["temperature"].max()
mean_Temp = df["temperature"].mean()
standardDeviation_temp = df["temperature"].std()
print(max_Temp, mean_Temp, standardDeviation_temp)
# Out:
# 35 30.333333333333332 3.8297084310253524

# %%
df.describe() # Gives all the statistics of the data
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
df[df.temperature >=35]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
df.set_index("day", inplace=True) # Sets the index to day

# %%
df.reset_index(inplace=True)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
import pandas as pd
df = pd.read_csv("stock_data.csv", skiprows=1) # Skiprows skips the first row or we can use header=1
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
df = pd.read_csv("stock_data.csv", header=None, names=["ticker","eps","revenue","people"])
df
# Out:
#                 ticker      eps revenue         people
# tickers            eps  revenue   price         people
# GOOGL            27.82       87     845     larry page
# WMT               4.61      484      65           n.a.
# MSFT                -1       85      64     bill gates
# RIL      not available       50    1023  mukesh ambani
# TATA               5.6       -1    n.a.     ratan tata

# %%
df = pd.read_csv("stock_data.csv", nrows=3) # nrows gives the number of rows to read
df
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.
# 2    MSFT  -1.00       85     64  bill gates

# %%
df = pd.read_csv("stock_data.csv", na_values=["not available", "n.a."])  # Replaces the values with NaN
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
df = pd.read_csv("stock_data.csv", na_values={
    'eps':["not available", "n.a."],
    'revenue':["not available", "n.a.", -1],
    'people':["not available", "n.a."]
})
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %%
df.to_csv("new.csv", index=False) # Saves the data to new.csv without index)

# %%
import pandas as pd

def convert_people_cell(cell):
    if cell=="n.a.":
        return 'Sam Walton'
    return cell

def convert_esp_cell(cell):
    if cell=="not available":
        return None
    return cell


df = pd.read_excel("stock_data.xlsx", "Sheet1", converters={
    'people': convert_people_cell
})
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65     Sam Walton
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df.to_excel("new.xlsx", sheet_name="stocks", index=False)

# %% [markdown]
# Handle Missing Data

# %%
import pandas as pd
df = pd.read_csv("weather_data (1).csv", parse_dates=["day"])
type(df.day[0])
df.set_index("day", inplace=True)
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna(0) # Fills the NaN values with 0
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        9.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08          0.0        0.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna({
    'temperature': 0,
    'windspeed': 0,
    'event': 'no event'
})
new_df
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        9.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  no event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08          0.0        0.0     Sunny
# 2017-01-09          0.0        0.0  no event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %%
new_df = df.fillna(method="ffill") # Forward fill fills the NaN values with the previous value
new_df
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4156\3465563308.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method="ffill") # Forward fill fills the NaN values with the previous value
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        7.0   Sunny
# 2017-01-09         32.0        7.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna(method="bfill") # Backward fill fills the NaN values with the next value
new_df
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4156\2530670963.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method="bfill") # Backward fill fills the NaN values with the next value
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         28.0        9.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         32.0        7.0    Rain
# 2017-01-07         32.0        8.0    Rain
# 2017-01-08         34.0        8.0   Sunny
# 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.interpolate()
new_df
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4156\812076388.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df = df.interpolate()
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    30.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
new_df = df.dropna()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.dropna(thresh=2)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-07         32.0        NaN    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
dt = pd.date_range("01-01-2017", "01-11-2017")
idx = pd.DatetimeIndex(dt)
df.reindex(idx)
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# Rplace function

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("weather_data (2).csv")
df
# Out:
#           day temperature windspeed  event
# 0  01-01-2017        32 F     6 mph   Rain
# 1  01-02-2017      -99999         7  Sunny
# 2  01-03-2017          28    -99999   Snow
# 3  01-04-2017      -99999         7      0
# 4  01-05-2017        32 C    -99999   Rain
# 5  01-06-2017          31         2  Sunny
# 6  01-06-2017          34         5      0

# %%
new_df = df.replace(-99999, value=np.nan) # Replaces -99999 with NaN or we can use dictionary to replace multiple values
new_df
# Out:
#           day temperature windspeed  event
# 0  01-01-2017        32 F     6 mph   Rain
# 1  01-02-2017      -99999         7  Sunny
# 2  01-03-2017          28    -99999   Snow
# 3  01-04-2017      -99999         7      0
# 4  01-05-2017        32 C    -99999   Rain
# 5  01-06-2017          31         2  Sunny
# 6  01-06-2017          34         5      0

# %%
new_df = df.replace({
    "temperature" : -99999,
    "windspeed" : -99999,
    "event" : "0"
},np.nan) # Replaces -99999 with NaN or we can use dictionary to replace multiple values
new_df
# Out:
#           day temperature windspeed  event
# 0  01-01-2017        32 F     6 mph   Rain
# 1  01-02-2017      -99999         7  Sunny
# 2  01-03-2017          28    -99999   Snow
# 3  01-04-2017      -99999         7    NaN
# 4  01-05-2017        32 C    -99999   Rain
# 5  01-06-2017          31         2  Sunny
# 6  01-06-2017          34         5    NaN

# %%
new_df = df.replace({
    -99999: np.nan,
    '0': 'sunny'
})
new_df
# Out:
#           day temperature windspeed  event
# 0  01-01-2017        32 F     6 mph   Rain
# 1  01-02-2017      -99999         7  Sunny
# 2  01-03-2017          28    -99999   Snow
# 3  01-04-2017      -99999         7  sunny
# 4  01-05-2017        32 C    -99999   Rain
# 5  01-06-2017          31         2  Sunny
# 6  01-06-2017          34         5  sunny

# %%
new_df = df.replace({
    'temperature': '[A-Za-z]',
    'windspeed': '[A-Za-z]'
},'',regex=True)

new_df
# Out:
#           day temperature windspeed  event
# 0  01-01-2017         32         6    Rain
# 1  01-02-2017      -99999         7  Sunny
# 2  01-03-2017          28    -99999   Snow
# 3  01-04-2017      -99999         7      0
# 4  01-05-2017         32     -99999   Rain
# 5  01-06-2017          31         2  Sunny
# 6  01-06-2017          34         5      0

# %%
import pandas as pd
df = pd.read_csv("weather_by_cities.csv")
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
g = df.groupby("city")
g

# %%
for city ,city_def in g: # Prints the data according to the city
    print(city)          
    print(city_def)
    print(" ")
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
#
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
#
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
g.get_group("mumbai") # Gets the group of mumbai
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain

# %%
g.max() # Gives the maximum value of each city
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
g.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# mumbai      Axes(0.125,0.11;0.775x0.77)
# new york    Axes(0.125,0.11;0.775x0.77)
# paris       Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# Cocate

# %%
import pandas as pd

india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df = pd.concat([india_weather, us_weather], ignore_index=True) # Concatenates the data
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
df = pd.concat([india_weather, us_weather], keys=["india","us"]) # Concatenates the data with keys
df
# Out:
#              city  temperature  humidity
# india 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# us    0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
df.loc["us"]
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df.loc["india"]
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
temperature_df = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
}, index=[0,1,2])
temperature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed_df = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "windspeed": [7,12,9],
}, index=[0,1,2])
windspeed_df
# Out:
#        city  windspeed
# 0    mumbai          7
# 1     delhi         12
# 2  banglore          9

# %%
df = pd.concat([temperature_df,windspeed_df], axis=1) # Concatenates the data
df
# Out:
#        city  temperature      city  windspeed
# 0    mumbai           32    mumbai          7
# 1     delhi           45     delhi         12
# 2  banglore           30  banglore          9

# %% [markdown]
# Mearge the data

# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.DataFrame({
    "city": ["new york", "chicago", "orlando", "baltimore"],
    "temperature": [21, 14, 35, 32],
})

ax = df1.plot.pie(y="temperature", labels=df1["city"], autopct="%1.1f%%", shadow=True, explode=(0, 0, 0.1, 0), startangle=90)
ax.set_ylabel('')
ax.set_title('City Temperature Distribution')

plt.show()

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san francisco"],
    "humidity": [65,68,71],
})

ax2 = df2.plot.pie(y="humidity", labels=df2["city"], autopct="%1.1f%%", shadow = True, explode = (0, 0.1, 0))
ax2.set_ylabel('')
ax2.set_title('City Humidity Distribution')
plt.show()

# %%
df = pd.merge(df1,df2,on = "city", how = "outer",indicator=True)
df
# Out:
#             city  temperature  humidity      _merge
# 0      baltimore         32.0       NaN   left_only
# 1        chicago         14.0      65.0        both
# 2       new york         21.0      68.0        both
# 3        orlando         35.0       NaN   left_only
# 4  san francisco          NaN      71.0  right_only

# %%
df1 = pd.DataFrame({
    "city": ["new york", "chicago", "orlando", "baltimore"],
    "temperature": [21, 14, 35, 38],
    "humidity": [60, 80, 40, 50],
})
df1
# Out:
#         city  temperature  humidity
# 0   new york           21        60
# 1    chicago           14        80
# 2    orlando           35        40
# 3  baltimore           38        50

# %%
df2 = pd.DataFrame({
    "city": ["chicago", "new york", "san diego"],
    "temperature": [21, 14, 35],
    "humidity": [65, 68, 71],
})
df2
# Out:
#         city  temperature  humidity
# 0    chicago           21        65
# 1   new york           14        68
# 2  san diego           35        71

# %%
df3 = pd.merge(df1,df2, on="city", how="outer", suffixes=('_first','_second'))
df3
# Out:
#         city  temperature_first  humidity_first  temperature_second  \
# 0  baltimore               38.0            50.0                 NaN
# 1    chicago               14.0            80.0                21.0
# 2   new york               21.0            60.0                14.0
# 3    orlando               35.0            40.0                 NaN
# 4  san diego                NaN             NaN                35.0
#
#    humidity_second
# 0              NaN
# 1             65.0
# 2             68.0
# 3              NaN
# 4             71.0

# %% [markdown]
# Pivot table

# %%
import pandas as pd
df = pd.read_csv("weather.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot(index = "date", columns= "city", values = "humidity")
# Out:
# city      beijing  mumbai  new york
# date
# 5/1/2017       26      80        56
# 5/2/2017       30      83        58
# 5/3/2017       35      85        60

# %%
df.pivot_table(index = "date", columns= "city", values = "temperature")
# Out:
# city      beijing  mumbai  new york
# date
# 5/1/2017     80.0    75.0      65.0
# 5/2/2017     77.0    78.0      66.0
# 5/3/2017     79.0    82.0      68.0

# %%
df = pd.read_csv("weather2.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
df.pivot_table(index = "city", columns="date", margins=True)
# Out:
#          humidity                 temperature
# date     5/1/2017 5/2/2017    All    5/1/2017 5/2/2017     All
# city
# mumbai      81.50    55.50  68.50       76.50     81.0  78.750
# new york    55.00    61.00  58.00       63.00     71.0  67.000
# All         68.25    58.25  63.25       69.75     76.0  72.875

# %%
df = pd.read_csv("weather3.csv")
df
# Out:
#         date      city  temperature  humidity
# 0   5/1/2017  new york           65        56
# 1   5/2/2017  new york           61        54
# 2   5/3/2017  new york           70        60
# 3  12/1/2017  new york           30        50
# 4  12/2/2017  new york           28        52
# 5  12/3/2017  new york           25        51

# %%
df.columns = df.columns.str.strip()
df["date"] = pd.to_datetime(df["date"])

# %%
df.pivot_table(index = pd.Grouper(freq = "M", key = "date"), columns="city")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4156\729105927.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.pivot_table(index = pd.Grouper(freq = "M", key = "date"), columns="city")
#              humidity temperature
# city         new york    new york
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  51.000000   27.666667

# %% [markdown]
# Melt function

# %%
import pandas as pd
df = pd.read_csv("weather (1).csv")
df
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
df1 = pd.melt(df,id_vars=["day"], var_name="city", value_name="temperature")
df1
# Out:
#           day     city  temperature
# 0      Monday  chicago           32
# 1     Tuesday  chicago           30
# 2   Wednesday  chicago           28
# 3    Thursday  chicago           22
# 4      Friday  chicago           30
# 5    Saturday  chicago           20
# 6      Sunday  chicago           25
# 7      Monday  chennai           75
# 8     Tuesday  chennai           77
# 9   Wednesday  chennai           75
# 10   Thursday  chennai           82
# 11     Friday  chennai           83
# 12   Saturday  chennai           81
# 13     Sunday  chennai           77
# 14     Monday   berlin           41
# 15    Tuesday   berlin           43
# 16  Wednesday   berlin           45
# 17   Thursday   berlin           38
# 18     Friday   berlin           30
# 19   Saturday   berlin           45
# 20     Sunday   berlin           47

# %% [markdown]
# STACK AND UNSTACK

# %%
import pandas as pd
df = pd.read_excel("stocks.xlsx",header=[0,1])
df
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %%
df_stack = df.stack(level=0)
df_stack
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4156\2783607647.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_stack = df.stack(level=0)
#                                    Company  Facebook  Google  Microsoft
# 0 Price                                NaT    155.00   955.0      66.00
#   Price to earnings ratio (P/E)        NaT     37.10    32.0      30.31
#   Unnamed: 0_level_0            2017-06-05       NaN     NaN        NaN
# 1 Price                                NaT    150.00   987.0      69.00
#   Price to earnings ratio (P/E)        NaT     36.98    31.3      30.56
#   Unnamed: 0_level_0            2017-06-06       NaN     NaN        NaN
# 2 Price                                NaT    153.00   963.0      62.00
# ...

# %%
df_stack.unstack()
# Out:
#   Company                                                  Facebook  \
#     Price Price to earnings ratio (P/E) Unnamed: 0_level_0    Price
# 0     NaT                           NaT         2017-06-05    155.0
# 1     NaT                           NaT         2017-06-06    150.0
# 2     NaT                           NaT         2017-06-07    153.0
# 3     NaT                           NaT         2017-06-08    155.0
# 4     NaT                           NaT         2017-06-09    156.0
#
#                                                     Google  \
#   Price to earnings ratio (P/E) Unnamed: 0_level_0   Price
# 0                         37.10                NaN   955.0
# 1                         36.98                NaN   987.0
# 2                         36.78                NaN   963.0
# 3                         36.11                NaN  1000.0
# 4                         37.07                NaN  1012.0
#
#                                                    Microsoft  \
# ...

# %% [markdown]
# Crosstab

# %%
import pandas as pd
df = pd.read_excel("survey.xls")
df
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima   Bangadesh  Female   31       Left
# 5    Kadir   Bangadesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7   Sudhir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
pd.crosstab([df.Sex],[ df.Handedness], margins=True) # Cross tabulation
# Out:
# Handedness  Left  Right  All
# Sex
# Female         2      3    5
# Male           5      2    7
# All            7      5   12

# %%
import numpy as np
pd.crosstab([df.Sex],[ df.Handedness],values=df.Age, aggfunc=np.average) # Cross tabulation
# Out:
# Handedness  Left  Right
# Sex
# Female      44.5   31.0
# Male        31.2   28.0

# %%
import pandas as pd
import sqlalchemy

# %%
import pandas as pd
df = pd.read_csv("aapl.csv", parse_dates = ["Date"], index_col = "Date")
df.head(5)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4156\1240927472.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("aapl.csv", parse_dates = ["Date"], index_col = "Date")
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107

# %% [markdown]
# Time series analysis

# %%
df.index
# Out:
# DatetimeIndex(['2017-07-07', '2017-07-06', '2017-07-05', '2017-07-03',
#                '2017-06-30', '2017-06-29', '2017-06-28', '2017-06-27',
#                '2017-06-26', '2017-06-23',
#                ...
#                '2016-07-22', '2016-07-21', '2016-07-20', '2016-07-19',
#                '2016-07-18', '2016-07-15', '2016-07-14', '2016-07-13',
#                '2016-07-12', '2016-07-11'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %%
f = df.Close.resample("Q").mean().plot(kind="pie") # Resamples the data according to the quarter
f
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4156\191054803.py:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   f = df.Close.resample("Q").mean().plot(kind="pie") # Resamples the data according to the quarter
# <Axes: ylabel='Close'>

# %%
import pandas as pd 
df = pd.read_csv("aapl_no_dates.csv")
df
# Out:
#       Open    High     Low   Close    Volume
# 0   153.17  153.33  152.22  153.18  16404088
# 1   153.58  155.45  152.89  155.45  27770715
# 2   154.34  154.45  153.46  153.93  25331662
# 3   153.90  155.81  153.78  154.45  26624926
# 4   155.02  155.98  154.48  155.37  21069647
# 5   155.25  155.54  154.40  154.99  21250798
# 6   155.19  155.19  146.02  148.98  64882657
# 7   145.74  146.09  142.51  145.42  72307330
# 8   147.16  147.45  145.15  146.59  34165445
# 9   147.50  147.50  143.84  145.16  31531232
# 10  143.32  144.48  142.21  144.29  32165373
# 11  143.78  144.50  142.20  142.27  50361093
# 12  143.66  146.74  143.66  146.34  32541404
# 13  146.87  146.87  144.94  145.01  24900073
# 14  145.52  146.07  144.61  145.87  21265751
# 15  145.77  146.70  145.12  145.63  19106294
# 16  145.13  147.16  145.11  146.28  35439389
# 17  147.17  148.28  145.38  145.82  25692361
# 18  145.01  146.16  143.62  143.73  24761891
# 19  144.49  146.11  143.16  145.83  22082432
# ...

# %%
rng = pd.date_range(start="6/1/2017", end="6/30/2017", freq="B")
rng
# Out:
# DatetimeIndex(['2017-06-01', '2017-06-02', '2017-06-05', '2017-06-06',
#                '2017-06-07', '2017-06-08', '2017-06-09', '2017-06-12',
#                '2017-06-13', '2017-06-14', '2017-06-15', '2017-06-16',
#                '2017-06-19', '2017-06-20', '2017-06-21', '2017-06-22',
#                '2017-06-23', '2017-06-26', '2017-06-27', '2017-06-28',
#                '2017-06-29', '2017-06-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
df.set_index(rng,inplace=True)
df
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-19  143.66  146.74  143.66  146.34  32541404
# 2017-06-20  146.87  146.87  144.94  145.01  24900073
# 2017-06-21  145.52  146.07  144.61  145.87  21265751
# 2017-06-22  145.77  146.70  145.12  145.63  19106294
# 2017-06-23  145.13  147.16  145.11  146.28  35439389
# ...

# %%
# %matplotlib inline
df.Close.plot()
# Out:
# <Axes: >

# %%
df["2017-06-01" : "2017-06-10"].Close.mean()
# Out:
# np.float64(153.7642857142857)

# %%
df.asfreq("D",method="pad") # Changes the frequency of the data to daily and fills the NaN values with the previous value
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-03  153.58  155.45  152.89  155.45  27770715
# 2017-06-04  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-10  155.19  155.19  146.02  148.98  64882657
# 2017-06-11  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-17  143.78  144.50  142.20  142.27  50361093
# ...

# %%
rng = pd.date_range(start= "1/1/2017", periods=72, freq="B")
rng
# Out:
# DatetimeIndex(['2017-01-02', '2017-01-03', '2017-01-04', '2017-01-05',
#                '2017-01-06', '2017-01-09', '2017-01-10', '2017-01-11',
#                '2017-01-12', '2017-01-13', '2017-01-16', '2017-01-17',
#                '2017-01-18', '2017-01-19', '2017-01-20', '2017-01-23',
#                '2017-01-24', '2017-01-25', '2017-01-26', '2017-01-27',
#                '2017-01-30', '2017-01-31', '2017-02-01', '2017-02-02',
#                '2017-02-03', '2017-02-06', '2017-02-07', '2017-02-08',
#                '2017-02-09', '2017-02-10', '2017-02-13', '2017-02-14',
#                '2017-02-15', '2017-02-16', '2017-02-17', '2017-02-20',
#                '2017-02-21', '2017-02-22', '2017-02-23', '2017-02-24',
#                '2017-02-27', '2017-02-28', '2017-03-01', '2017-03-02',
#                '2017-03-03', '2017-03-06', '2017-03-07', '2017-03-08',
#                '2017-03-09', '2017-03-10', '2017-03-13', '2017-03-14',
# ...

# %%
import numpy as np
ts = pd.Series(np.random.randint(1,10,len(rng)), index = rng)
ts.head(10)
# Out:
# 2017-01-02    7
# 2017-01-03    2
# 2017-01-04    9
# 2017-01-05    5
# 2017-01-06    9
# 2017-01-09    9
# 2017-01-10    9
# 2017-01-11    3
# 2017-01-12    6
# 2017-01-13    4
# Freq: B, dtype: int32

# %%
import pandas as pd
df = pd.read_csv("aapl_no_dates (1).csv")
df.head()
# Out:
#      Open    High     Low   Close    Volume
# 0  144.88  145.30  143.10  143.50  14277848
# 1  143.69  144.79  142.72  144.09  21569557
# 2  143.02  143.50  142.41  142.73  24128782
# 3  142.90  144.75  142.90  144.18  19201712
# 4  144.11  145.95  143.37  145.06  21090636

# %%
pd.date_range(start= "7/1/2017", end = "7/21/2017", freq="B")
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-04', '2017-07-05', '2017-07-06',
#                '2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14', '2017-07-17', '2017-07-18',
#                '2017-07-19', '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', freq='B')

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar 
from pandas.tseries.offsets import CustomBusinessDay

usb =  CustomBusinessDay(calendar=USFederalHolidayCalendar()) # Custom Business Day excluding the holidays in the US Federal Holiday Calendar 
usb

# %%
rng = pd.date_range(start= "7/1/2017", end = "7/21/2017", freq=usb) # Excludes the holidays in the US Federal Holiday Calendar 
rng
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-05', '2017-07-06', '2017-07-07',
#                '2017-07-10', '2017-07-11', '2017-07-12', '2017-07-13',
#                '2017-07-14', '2017-07-17', '2017-07-18', '2017-07-19',
#                '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', freq='C')

# %%
df.set_index(rng, inplace=True)
df
# Out:
#               Open    High     Low   Close    Volume
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-10  144.11  145.95  143.37  145.06  21090636
# 2017-07-11  144.73  145.85  144.38  145.53  19781836
# 2017-07-12  145.87  146.18  144.82  145.74  24884478
# 2017-07-13  145.50  148.49  145.44  147.77  25199373
# 2017-07-14  147.97  149.33  147.33  149.04  20132061
# 2017-07-17  148.82  150.90  148.57  149.56  23793456
# 2017-07-18  149.20  150.13  148.67  150.08  17868792
# 2017-07-19  150.48  151.42  149.95  151.02  20922969
# 2017-07-20  151.50  151.74  150.19  150.34  17243748
# 2017-07-21  149.99  150.44  148.88  150.27  26252630

# %%
import pandas as pd

dates = ["2017-01-05", "Jan 5, 2017", "01/05/2017", "2017.01.05", "2017/01/05", "20170105"]
# Use format='mixed' to handle the different date formats
parsed_dates = pd.to_datetime(dates, format='mixed')
print(parsed_dates)
# Out:
# DatetimeIndex(['2017-01-05', '2017-01-05', '2017-01-05', '2017-01-05',
#                '2017-01-05', '2017-01-05'],
#               dtype='datetime64[ns]', freq=None)

# %%
idx = pd.period_range("2011", periods= 10, freq="Q-JAN")
idx
# Out:
# PeriodIndex(['2011Q4', '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1',
#              '2013Q2', '2013Q3', '2013Q4', '2014Q1'],
#             dtype='period[Q-JAN]')

# %%
import numpy as np
ps = pd.Series(np.random.randn(len(idx)), idx)
ps
# Out:
# 2011Q4    0.662721
# 2012Q1   -0.113657
# 2012Q2    3.780556
# 2012Q3    0.813879
# 2012Q4   -1.917195
# 2013Q1    0.562613
# 2013Q2    0.951559
# 2013Q3    1.563432
# 2013Q4    1.073097
# 2014Q1   -0.930882
# Freq: Q-JAN, dtype: float64

# %%
import pandas as pd
df = pd.read_csv("wmt.csv")
df
# Out:
#   Line Item  2017Q1  2017Q2  2017Q3  2017Q4  2018Q1
# 0   Revenue  115904  120854  118179  130936  117542
# 1  Expenses   86544   89485   87484   97743   87688
# 2    Profit   29360   31369   30695   33193   29854

# %%
df = df.T
df
# Out:
#                  0         1       2
# Line Item  Revenue  Expenses  Profit
# 2017Q1      115904     86544   29360
# 2017Q2      120854     89485   31369
# 2017Q3      118179     87484   30695
# 2017Q4      130936     97743   33193
# 2018Q1      117542     87688   29854

# %%
df.index = pd.to_datetime(df.index, errors='coerce')  # Replace invalid dates with NaT
df.index
# Out:
# DatetimeIndex(['NaT', '2017-01-01', '2017-04-01', '2017-07-01', '2017-10-01',
#                '2018-01-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
df.index = pd.PeriodIndex(df.index, freq="Q-JAN")

# %%
# Step 1: Convert to PeriodIndex if needed
df.index = pd.to_datetime(df.index, errors='coerce')  # Ensure valid date values
df.index = df.index.to_period(freq="Q-JAN")  # Convert to PeriodIndex

# Step 2: Map start_time safely
df["start date"] = df.index.map(lambda x: x.start_time if pd.notna(x) else pd.NaT)
df
# Out:
#            0         1       2 start date
# NaT  Revenue  Expenses  Profit        NaT
# NaT   115904     86544   29360        NaT
# NaT   120854     89485   31369        NaT
# NaT   118179     87484   30695        NaT
# NaT   130936     97743   33193        NaT
# NaT   117542     87688   29854        NaT

# %%
import pandas as pd

df = pd.read_csv("msft.csv", header=1, index_col="Date Time", parse_dates=True)
df
# Out:
#                      Price
# Date Time
# 2017-08-17 09:00:00  72.38
# 2017-08-17 09:15:00  71.00
# 2017-08-17 09:30:00  71.67
# 2017-08-17 10:00:00  72.80
# 2017-08-17 10:30:00  73.00
# 2017-08-17 11:00:00  72.50

# %%
df.index
# Out:
# DatetimeIndex(['2017-08-17 09:00:00', '2017-08-17 09:15:00',
#                '2017-08-17 09:30:00', '2017-08-17 10:00:00',
#                '2017-08-17 10:30:00', '2017-08-17 11:00:00'],
#               dtype='datetime64[ns]', name='Date Time', freq=None)

# %%
df = df.tz_localize(tz = "US/Eastern") # Localizes the time zone to US/Eastern

# %%
df.index
# Out:
# DatetimeIndex(['2017-08-17 09:00:00-04:00', '2017-08-17 09:15:00-04:00',
#                '2017-08-17 09:30:00-04:00', '2017-08-17 10:00:00-04:00',
#                '2017-08-17 10:30:00-04:00', '2017-08-17 11:00:00-04:00'],
#               dtype='datetime64[ns, US/Eastern]', name='Date Time', freq=None)

# %%
df = df.tz_convert(tz = "Europe/Berlin") # Converts the time zone to Europe/Berlin
df
# Out:
#                            Price
# Date Time
# 2017-08-17 15:00:00+02:00  72.38
# 2017-08-17 15:15:00+02:00  71.00
# 2017-08-17 15:30:00+02:00  71.67
# 2017-08-17 16:00:00+02:00  72.80
# 2017-08-17 16:30:00+02:00  73.00
# 2017-08-17 17:00:00+02:00  72.50

# %%
from pytz import all_timezones
all_timezones
# Out:
# ['Africa/Abidjan',
#  'Africa/Accra',
#  'Africa/Addis_Ababa',
#  'Africa/Algiers',
#  'Africa/Asmara',
#  'Africa/Asmera',
#  'Africa/Bamako',
#  'Africa/Bangui',
#  'Africa/Banjul',
#  'Africa/Bissau',
#  'Africa/Blantyre',
#  'Africa/Brazzaville',
#  'Africa/Bujumbura',
#  'Africa/Cairo',
#  'Africa/Casablanca',
#  'Africa/Ceuta',
#  'Africa/Conakry',
#  'Africa/Dakar',
#  'Africa/Dar_es_Salaam',
#  'Africa/Djibouti',
#  'Africa/Douala',
#  'Africa/El_Aaiun',
#  'Africa/Freetown',
#  'Africa/Gaborone',
#  'Africa/Harare',
#  'Africa/Johannesburg',
#  'Africa/Juba',
#  'Africa/Kampala',
#  'Africa/Khartoum',
#  'Africa/Kigali',
#  'Africa/Kinshasa',
#  'Africa/Lagos',
#  'Africa/Libreville',
#  'Africa/Lome',
#  'Africa/Luanda',
#  'Africa/Lubumbashi',
#  'Africa/Lusaka',
#  'Africa/Malabo',
#  'Africa/Maputo',
#  'Africa/Maseru',
#  'Africa/Mbabane',
#  'Africa/Mogadishu',
#  'Africa/Monrovia',
#  'Africa/Nairobi',
#  'Africa/Ndjamena',
#  'Africa/Niamey',
#  'Africa/Nouakchott',
# ...

# %%
df = df.tz_convert(tz = 'Asia/Kolkata')
df
# Out:
#                            Price
# Date Time
# 2017-08-17 18:30:00+05:30  72.38
# 2017-08-17 18:45:00+05:30  71.00
# 2017-08-17 19:00:00+05:30  71.67
# 2017-08-17 19:30:00+05:30  72.80
# 2017-08-17 20:00:00+05:30  73.00
# 2017-08-17 20:30:00+05:30  72.50

# %%
rng = pd.date_range(start="1/1/2017", periods=10, freq="H", tz="dateutil/Europe/London")
rng
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4156\1346521293.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   rng = pd.date_range(start="1/1/2017", periods=10, freq="H", tz="dateutil/Europe/London")
# DatetimeIndex(['2017-01-01 00:00:00+00:00', '2017-01-01 01:00:00+00:00',
#                '2017-01-01 02:00:00+00:00', '2017-01-01 03:00:00+00:00',
#                '2017-01-01 04:00:00+00:00', '2017-01-01 05:00:00+00:00',
#                '2017-01-01 06:00:00+00:00', '2017-01-01 07:00:00+00:00',
#                '2017-01-01 08:00:00+00:00', '2017-01-01 09:00:00+00:00'],
#               dtype='datetime64[ns, tzfile('GB-Eire')]', freq='h')

# %% [markdown]
# shifting

# %%
import pandas as pd
df = pd.read_csv("fb.csv", parse_dates=["Date"], index_col="Date")
df
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4156\1447845448.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("fb.csv", parse_dates=["Date"], index_col="Date")
#              Price
# Date
# 2017-08-15  171.00
# 2017-08-16  170.00
# 2017-08-17  166.91
# 2017-08-18  167.41
# 2017-08-21  167.78
# 2017-08-22  169.64
# 2017-08-23  168.71
# 2017-08-24  167.74
# 2017-08-25  166.32
# 2017-08-28  167.24

# %%
import matplotlib.pyplot as plt

df['Price'].plot(title='Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df = df.shift(1)

# %%
import matplotlib.pyplot as plt

df['Price'].plot(title='Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df.shift(2)
# Out:
#              Price
# Date
# 2017-08-15     NaN
# 2017-08-16     NaN
# 2017-08-17     NaN
# 2017-08-18  171.00
# 2017-08-21  170.00
# 2017-08-22  166.91
# 2017-08-23  167.41
# 2017-08-24  167.78
# 2017-08-25  169.64
# 2017-08-28  168.71

# %%
import matplotlib.pyplot as plt

df['Price'].plot(title='Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df["Prev Day Price "] = df["Price"].shift(1)
df
# Out:
#              Price  Prev Day Price
# Date
# 2017-08-15     NaN              NaN
# 2017-08-16  171.00              NaN
# 2017-08-17  170.00           171.00
# 2017-08-18  166.91           170.00
# 2017-08-21  167.41           166.91
# 2017-08-22  167.78           167.41
# 2017-08-23  169.64           167.78
# 2017-08-24  168.71           169.64
# 2017-08-25  167.74           168.71
# 2017-08-28  166.32           167.74

# %%
df["1 day change"] = df["Price"] - df["Prev Day Price "]
df
# Out:
#              Price  Prev Day Price   1 day change
# Date
# 2017-08-15     NaN              NaN           NaN
# 2017-08-16  171.00              NaN           NaN
# 2017-08-17  170.00           171.00         -1.00
# 2017-08-18  166.91           170.00         -3.09
# 2017-08-21  167.41           166.91          0.50
# 2017-08-22  167.78           167.41          0.37
# 2017-08-23  169.64           167.78          1.86
# 2017-08-24  168.71           169.64         -0.93
# 2017-08-25  167.74           168.71         -0.97
# 2017-08-28  166.32           167.74         -1.42

# %%
df["5 Day % return"] = (df["Price"] - df["Price"].shift(5))*100/df["Price"].shift(5)
df
# Out:
#              Price  Prev Day Price   1 day change  5 Day % return
# Date
# 2017-08-15     NaN              NaN           NaN             NaN
# 2017-08-16  171.00              NaN           NaN             NaN
# 2017-08-17  170.00           171.00         -1.00             NaN
# 2017-08-18  166.91           170.00         -3.09             NaN
# 2017-08-21  167.41           166.91          0.50             NaN
# 2017-08-22  167.78           167.41          0.37             NaN
# 2017-08-23  169.64           167.78          1.86       -0.795322
# 2017-08-24  168.71           169.64         -0.93       -0.758824
# 2017-08-25  167.74           168.71         -0.97        0.497274
# 2017-08-28  166.32           167.74         -1.42       -0.651096

# %%
df = df [ ["Price"]]
df
# Out:
#              Price
# Date
# 2017-08-15     NaN
# 2017-08-16  171.00
# 2017-08-17  170.00
# 2017-08-18  166.91
# 2017-08-21  167.41
# 2017-08-22  167.78
# 2017-08-23  169.64
# 2017-08-24  168.71
# 2017-08-25  167.74
# 2017-08-28  166.32
